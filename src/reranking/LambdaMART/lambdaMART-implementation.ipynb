# %%
import pyltr
import numpy as np
import sklearn.tree
import random
import math
import os
import pickle

# %%
NUM_TREES = 50
DATA_FOLDER = 'data/'
EXPERIMENTS = ['long-tail','noisy','query-length/c1','query-length/c2','query-length/c3','']
#EXPERIMENTS  = ['']

NUM_EXPERIMENTS = 10
MODES = ['train','val','test']
feature_idxes = [19,4]

# %%
file_dict = {
    'long-tail' :{
        'train': 'train_longtail_suggest_matrix.npz',
        'val': 'val_longtail_suggest_matrix.npz',
        'test': 'test_longtail_suggest_matrix.npz',
    },
    'noisy' :{
        'train': 'tr_noisy_suggest_matrix.npz',
        'val': 'val_noisy_suggest_matrix.npz',
        'test': 'test_noisy_suggest_matrix.npz',
    },
    'query-length/c1' : {
        'train': 'tr_c1_suggest_matrix.npz',
        'val': 'val_c1_suggest_matrix.npz',
        'test': 'test_c1_suggest_matrix.npz',
    },
    'query-length/c2' : {
        'train': 'tr_c2_suggest_matrix.npz',
        'val': 'val_c2_suggest_matrix.npz',
        'test': 'test_c2_suggest_matrix.npz',
    },
    'query-length/c3': {
        'train': 'tr_c3_suggest_matrix.npz',
        'val': 'val_c3_suggest_matrix.npz',
        'test': 'test_c3_suggest_matrix.npz',
    },
    '' : {
        'train': 'train_suggest_matrix.npz',
        'val': 'val_suggest_matrix.npz',
        'test': 'test_suggest_matrix.npz',
    }
}

#col0=anchor ID, col1=suggestion ID. col 2-19 features, col 19 is scores
def make_sessions_ids(anchor_ids):
    
    sessions_ids = np.zeros([len(anchor_ids)])
    iters = len(anchor_ids) /20
    for i in range(iters):
        sessions_ids[i*20:(i+1)*20] = i
    return sessions_ids

def make_data(data_folder, experiment, file_dict,mode ,feature_idx=20):
            
        path = os.path.join(data_folder, experiment, file_dict[experiment][mode] )
        
        print path
        data_train = np.load(path)['arr_0']
       
        data_anchor_ids = data_train[:,0]
        data_suggestion_ids = data_train[:,1]
        data_features = data_train[:,3:feature_idx]
        data_label_scores = data_train[:,20]
        data_session_ids = make_sessions_ids(data_anchor_ids)
        
        return data_anchor_ids, data_suggestion_ids, data_features, data_label_scores, data_session_ids
    
def MRR_Score(Epred, test_data_session_ids, test_data_label_scores, session_length=20):
    sessions = len(test_data_session_ids)/session_length
    idx_array = []

    for session_idx in range(0, sessions):
        predicted_scores = Epred[session_idx*session_length:(session_idx +1)*session_length]
        labels = test_data_label_scores[session_idx*session_length:(session_idx +1)*session_length]
        merged = np.array([predicted_scores, labels]).T
        
        merged = merged[merged[:, 0].argsort()]

        pred_idx = np.argmax(merged[:,1][::-1]) 
        idx_array.append(pred_idx)


    sum_score = 0
    for i,val in enumerate(idx_array): 
        sum_score += (1./(val+1))
    return sum_score / sessions

# %%
"""
Some small demo's
metric = pyltr.metrics.NDCG(k=20)

model = pyltr.models.LambdaMART(
    metric=metric,
    n_estimators=n_trees,
    learning_rate=1./n_trees,
    max_features=0.3,
    query_subsample=(1./n_trees),
    max_leaf_nodes=10,
    min_samples_leaf=200,
    verbose=1,
    random_state=None
)           

monitor = pyltr.models.monitors.ValidationMonitor(
    val_data_features, val_data_label_scores, val_data_session_ids, metric=metric, stop_after=5)
    
    model.fit(train_data_features, train_data_label_scores, train_data_session_ids)
    
    Epred = model.predict(test_data_features)

print 'Random ranking:', metric.calc_mean_random(val_data_session_ids, val_data_label_scores)
print 'Our model:', metric.calc_mean(test_data_session_ids, test_data_label_scores, Epred)

print MMR_Score(Epred, test_data_session_ids, test_data_label_scores)

"""
# Out:
# "\nSome small demo's\nmetric = pyltr.metrics.NDCG(k=20)\n\nmodel = pyltr.models.LambdaMART(\n    metric=metric,\n    n_estimators=n_trees,\n    learning_rate=1./n_trees,\n    max_features=0.3,\n    query_subsample=(1./n_trees),\n    max_leaf_nodes=10,\n    min_samples_leaf=200,\n    verbose=1,\n    random_state=None\n)           \n\nmonitor = pyltr.models.monitors.ValidationMonitor(\n    val_data_features, val_data_label_scores, val_data_session_ids, metric=metric, stop_after=5)\n    \n    model.fit(train_data_features, train_data_label_scores, train_data_session_ids)\n    \n    Epred = model.predict(test_data_features)\n\nprint 'Random ranking:', metric.calc_mean_random(val_data_session_ids, val_data_label_scores)\nprint 'Our model:', metric.calc_mean(test_data_session_ids, test_data_label_scores, Epred)\n\nprint MMR_Score(Epred, test_data_session_ids, test_data_label_scores)\n\n"

# %%
metric = pyltr.metrics.NDCG(k=20)

for feature_idx in feature_idxes:
    result_dict = {
        'long-tail' :[],
        'noisy' :[],
        'query-length/c1' : [],
        'query-length/c2' : [],
        'query-length/c3': [],
        '' : []
    }
    for experiment in EXPERIMENTS:
        for epoch in range(NUM_EXPERIMENTS):
            print "--- new experiment ---" 
            train_data_anchor_ids, train_data_suggestion_ids, train_data_features, \
            train_data_label_scores, train_data_session_ids =  make_data(DATA_FOLDER, experiment, file_dict,'train' ,feature_idx=feature_idx)
            val_data_anchor_ids, val_data_suggestion_ids, val_data_features, \
            val_data_label_scores, val_data_session_ids =  make_data(DATA_FOLDER, experiment, file_dict,'val' ,feature_idx=feature_idx) 

            test_data_anchor_ids, test_data_suggestion_ids, test_data_features, \
            test_data_label_scores, test_data_session_ids =  make_data(DATA_FOLDER, experiment, file_dict,'test' ,feature_idx=feature_idx) 

            model = pyltr.models.LambdaMART(
                metric=metric,
                n_estimators=NUM_TREES,
                learning_rate=1./NUM_TREES,
                max_features=0.3,
                query_subsample=(1./NUM_TREES),
                max_leaf_nodes=10,
                min_samples_leaf=200,
                verbose=0,
                random_state=None
            )

            model.fit(train_data_features, train_data_label_scores, train_data_session_ids)

            Epred = model.predict(test_data_features)

            random_ranking = metric.calc_mean_random(val_data_session_ids, val_data_label_scores)
            model_ndcg = metric.calc_mean(test_data_session_ids, test_data_label_scores, Epred)
            mrr_score = MRR_Score(Epred, test_data_session_ids, test_data_label_scores)
            print "Experiment: ", epoch + 1
            print "MMR Score for " + experiment + " : ", mrr_score
            result_dict[experiment].append(mrr_score)
    pickle.dump( result_dict, open( 'results/' + str(feature_idx)+ '_' + str(experiment) + "results_save.p", "wb" ) )
    print "__________________________________________________"
# Out:
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  1
# MMR Score for long-tail :  0.43311105393
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  2
# MMR Score for long-tail :  0.41355242083
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  3
# MMR Score for long-tail :  0.405854653196
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  4
# MMR Score for long-tail :  0.465006915444
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  5
# MMR Score for long-tail :  0.468370729385
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  6
# MMR Score for long-tail :  0.43089339956
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  7
# MMR Score for long-tail :  0.415987233671
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  8
# MMR Score for long-tail :  0.470196456406
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  9
# MMR Score for long-tail :  0.427679341612
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  10
# MMR Score for long-tail :  0.446666071689
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  11
# MMR Score for long-tail :  0.458400718421
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  12
# MMR Score for long-tail :  0.434987123869
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  13
# MMR Score for long-tail :  0.438603337486
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  14
# MMR Score for long-tail :  0.443586604749
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  15
# MMR Score for long-tail :  0.437128893104
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  16
# MMR Score for long-tail :  0.407930334555
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  17
# MMR Score for long-tail :  0.441381811294
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  18
# MMR Score for long-tail :  0.415846623399
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  19
# MMR Score for long-tail :  0.468661124685
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  20
# MMR Score for long-tail :  0.443855179283
# --- new experiment ---
# data/noisy/tr_noisy_suggest_matrix.npz
# data/noisy/val_noisy_suggest_matrix.npz
# data/noisy/test_noisy_suggest_matrix.npz
# Experiment:  1
# MMR Score for noisy :  0.442512033102
# --- new experiment ---
# data/noisy/tr_noisy_suggest_matrix.npz
# data/noisy/val_noisy_suggest_matrix.npz
# data/noisy/test_noisy_suggest_matrix.npz
# Experiment:  2
# MMR Score for noisy :  0.432521547375
# --- new experiment ---
# data/noisy/tr_noisy_suggest_matrix.npz
# data/noisy/val_noisy_suggest_matrix.npz
# data/noisy/test_noisy_suggest_matrix.npz
# Experiment:  3
# MMR Score for noisy :  0.449090623908
# --- new experiment ---
# data/noisy/tr_noisy_suggest_matrix.npz
# data/noisy/val_noisy_suggest_matrix.npz
# data/noisy/test_noisy_suggest_matrix.npz
# Experiment:  4
# MMR Score for noisy :  0.441836427528
# --- new experiment ---
# data/noisy/tr_noisy_suggest_matrix.npz
# data/noisy/val_noisy_suggest_matrix.npz
# data/noisy/test_noisy_suggest_matrix.npz
# Experiment:  5
# MMR Score for noisy :  0.446959168703
# --- new experiment ---
# data/noisy/tr_noisy_suggest_matrix.npz
# data/noisy/val_noisy_suggest_matrix.npz
# data/noisy/test_noisy_suggest_matrix.npz
# Experiment:  6
# MMR Score for noisy :  0.43936412468
# --- new experiment ---
# data/noisy/tr_noisy_suggest_matrix.npz
# data/noisy/val_noisy_suggest_matrix.npz
# data/noisy/test_noisy_suggest_matrix.npz
# Experiment:  7
# MMR Score for noisy :  0.442229141888
# --- new experiment ---
# data/noisy/tr_noisy_suggest_matrix.npz
# data/noisy/val_noisy_suggest_matrix.npz
# data/noisy/test_noisy_suggest_matrix.npz
# Experiment:  8
# MMR Score for noisy :  0.44142934333
# --- new experiment ---
# data/noisy/tr_noisy_suggest_matrix.npz
# data/noisy/val_noisy_suggest_matrix.npz
# data/noisy/test_noisy_suggest_matrix.npz
# Experiment:  9
# MMR Score for noisy :  0.441221231101
# --- new experiment ---
# data/noisy/tr_noisy_suggest_matrix.npz
# data/noisy/val_noisy_suggest_matrix.npz
# data/noisy/test_noisy_suggest_matrix.npz
# Experiment:  10
# MMR Score for noisy :  0.444166510876
# --- new experiment ---
# data/noisy/tr_noisy_suggest_matrix.npz
# data/noisy/val_noisy_suggest_matrix.npz
# data/noisy/test_noisy_suggest_matrix.npz
# Experiment:  11
# MMR Score for noisy :  0.446441995663
# --- new experiment ---
# data/noisy/tr_noisy_suggest_matrix.npz
# data/noisy/val_noisy_suggest_matrix.npz
# data/noisy/test_noisy_suggest_matrix.npz
# Experiment:  12
# MMR Score for noisy :  0.436393597967
# --- new experiment ---
# data/noisy/tr_noisy_suggest_matrix.npz
# data/noisy/val_noisy_suggest_matrix.npz
# data/noisy/test_noisy_suggest_matrix.npz
# Experiment:  13
# MMR Score for noisy :  0.447205483926
# --- new experiment ---
# data/noisy/tr_noisy_suggest_matrix.npz
# data/noisy/val_noisy_suggest_matrix.npz
# data/noisy/test_noisy_suggest_matrix.npz
# Experiment:  14
# MMR Score for noisy :  0.451678003098
# --- new experiment ---
# data/noisy/tr_noisy_suggest_matrix.npz
# data/noisy/val_noisy_suggest_matrix.npz
# data/noisy/test_noisy_suggest_matrix.npz
# Experiment:  15
# MMR Score for noisy :  0.430149765565
# --- new experiment ---
# data/noisy/tr_noisy_suggest_matrix.npz
# data/noisy/val_noisy_suggest_matrix.npz
# data/noisy/test_noisy_suggest_matrix.npz
# Experiment:  16
# MMR Score for noisy :  0.436662123476
# --- new experiment ---
# data/noisy/tr_noisy_suggest_matrix.npz
# data/noisy/val_noisy_suggest_matrix.npz
# data/noisy/test_noisy_suggest_matrix.npz
# Experiment:  17
# MMR Score for noisy :  0.440046688106
# --- new experiment ---
# data/noisy/tr_noisy_suggest_matrix.npz
# data/noisy/val_noisy_suggest_matrix.npz
# data/noisy/test_noisy_suggest_matrix.npz
# Experiment:  18
# MMR Score for noisy :  0.441545238828
# --- new experiment ---
# data/noisy/tr_noisy_suggest_matrix.npz
# data/noisy/val_noisy_suggest_matrix.npz
# data/noisy/test_noisy_suggest_matrix.npz
# Experiment:  19
# MMR Score for noisy :  0.449845634024
# --- new experiment ---
# data/noisy/tr_noisy_suggest_matrix.npz
# data/noisy/val_noisy_suggest_matrix.npz
# data/noisy/test_noisy_suggest_matrix.npz
# Experiment:  20
# MMR Score for noisy :  0.442104325399
# --- new experiment ---
# data/query-length/c1/tr_c1_suggest_matrix.npz
# data/query-length/c1/val_c1_suggest_matrix.npz
# data/query-length/c1/test_c1_suggest_matrix.npz
# Experiment:  1
# MMR Score for query-length/c1 :  0.442887709777
# --- new experiment ---
# data/query-length/c1/tr_c1_suggest_matrix.npz
# data/query-length/c1/val_c1_suggest_matrix.npz
# data/query-length/c1/test_c1_suggest_matrix.npz
# Experiment:  2
# MMR Score for query-length/c1 :  0.440417771654
# --- new experiment ---
# data/query-length/c1/tr_c1_suggest_matrix.npz
# data/query-length/c1/val_c1_suggest_matrix.npz
# data/query-length/c1/test_c1_suggest_matrix.npz
# Experiment:  3
# MMR Score for query-length/c1 :  0.427873777334
# --- new experiment ---
# data/query-length/c1/tr_c1_suggest_matrix.npz
# data/query-length/c1/val_c1_suggest_matrix.npz
# data/query-length/c1/test_c1_suggest_matrix.npz
# Experiment:  4
# MMR Score for query-length/c1 :  0.440454773932
# --- new experiment ---
# data/query-length/c1/tr_c1_suggest_matrix.npz
# data/query-length/c1/val_c1_suggest_matrix.npz
# data/query-length/c1/test_c1_suggest_matrix.npz
# Experiment:  5
# MMR Score for query-length/c1 :  0.433089049597
# --- new experiment ---
# data/query-length/c1/tr_c1_suggest_matrix.npz
# data/query-length/c1/val_c1_suggest_matrix.npz
# data/query-length/c1/test_c1_suggest_matrix.npz
# Experiment:  6
# MMR Score for query-length/c1 :  0.451228442681
# --- new experiment ---
# data/query-length/c1/tr_c1_suggest_matrix.npz
# data/query-length/c1/val_c1_suggest_matrix.npz
# data/query-length/c1/test_c1_suggest_matrix.npz
# Experiment:  7
# MMR Score for query-length/c1 :  0.440686696196
# --- new experiment ---
# data/query-length/c1/tr_c1_suggest_matrix.npz
# data/query-length/c1/val_c1_suggest_matrix.npz
# data/query-length/c1/test_c1_suggest_matrix.npz
# Experiment:  8
# MMR Score for query-length/c1 :  0.44607600108
# --- new experiment ---
# data/query-length/c1/tr_c1_suggest_matrix.npz
# data/query-length/c1/val_c1_suggest_matrix.npz
# data/query-length/c1/test_c1_suggest_matrix.npz
# Experiment:  9
# MMR Score for query-length/c1 :  0.443738900547
# --- new experiment ---
# data/query-length/c1/tr_c1_suggest_matrix.npz
# data/query-length/c1/val_c1_suggest_matrix.npz
# data/query-length/c1/test_c1_suggest_matrix.npz
# Experiment:  10
# MMR Score for query-length/c1 :  0.43697585849
# --- new experiment ---
# data/query-length/c1/tr_c1_suggest_matrix.npz
# data/query-length/c1/val_c1_suggest_matrix.npz
# data/query-length/c1/test_c1_suggest_matrix.npz
# Experiment:  11
# MMR Score for query-length/c1 :  0.437030556176
# --- new experiment ---
# data/query-length/c1/tr_c1_suggest_matrix.npz
# data/query-length/c1/val_c1_suggest_matrix.npz
# data/query-length/c1/test_c1_suggest_matrix.npz
# Experiment:  12
# MMR Score for query-length/c1 :  0.450127952865
# --- new experiment ---
# data/query-length/c1/tr_c1_suggest_matrix.npz
# data/query-length/c1/val_c1_suggest_matrix.npz
# data/query-length/c1/test_c1_suggest_matrix.npz
# Experiment:  13
# MMR Score for query-length/c1 :  0.434625521469
# --- new experiment ---
# data/query-length/c1/tr_c1_suggest_matrix.npz
# data/query-length/c1/val_c1_suggest_matrix.npz
# data/query-length/c1/test_c1_suggest_matrix.npz
# Experiment:  14
# MMR Score for query-length/c1 :  0.438812143728
# --- new experiment ---
# data/query-length/c1/tr_c1_suggest_matrix.npz
# data/query-length/c1/val_c1_suggest_matrix.npz
# data/query-length/c1/test_c1_suggest_matrix.npz
# Experiment:  15
# MMR Score for query-length/c1 :  0.44049633288
# --- new experiment ---
# data/query-length/c1/tr_c1_suggest_matrix.npz
# data/query-length/c1/val_c1_suggest_matrix.npz
# data/query-length/c1/test_c1_suggest_matrix.npz
# Experiment:  16
# MMR Score for query-length/c1 :  0.436167113059
# --- new experiment ---
# data/query-length/c1/tr_c1_suggest_matrix.npz
# data/query-length/c1/val_c1_suggest_matrix.npz
# data/query-length/c1/test_c1_suggest_matrix.npz
# Experiment:  17
# MMR Score for query-length/c1 :  0.434957549656
# --- new experiment ---
# data/query-length/c1/tr_c1_suggest_matrix.npz
# data/query-length/c1/val_c1_suggest_matrix.npz
# data/query-length/c1/test_c1_suggest_matrix.npz
# Experiment:  18
# MMR Score for query-length/c1 :  0.433345294886
# --- new experiment ---
# data/query-length/c1/tr_c1_suggest_matrix.npz
# data/query-length/c1/val_c1_suggest_matrix.npz
# data/query-length/c1/test_c1_suggest_matrix.npz
# Experiment:  19
# MMR Score for query-length/c1 :  0.438738624968
# --- new experiment ---
# data/query-length/c1/tr_c1_suggest_matrix.npz
# data/query-length/c1/val_c1_suggest_matrix.npz
# data/query-length/c1/test_c1_suggest_matrix.npz
# Experiment:  20
# MMR Score for query-length/c1 :  0.43834904553
# --- new experiment ---
# data/query-length/c2/tr_c2_suggest_matrix.npz
# data/query-length/c2/val_c2_suggest_matrix.npz
# data/query-length/c2/test_c2_suggest_matrix.npz
# Experiment:  1
# MMR Score for query-length/c2 :  0.453468557181
# --- new experiment ---
# data/query-length/c2/tr_c2_suggest_matrix.npz
# data/query-length/c2/val_c2_suggest_matrix.npz
# data/query-length/c2/test_c2_suggest_matrix.npz
# Experiment:  2
# MMR Score for query-length/c2 :  0.455463994008
# --- new experiment ---
# data/query-length/c2/tr_c2_suggest_matrix.npz
# data/query-length/c2/val_c2_suggest_matrix.npz
# data/query-length/c2/test_c2_suggest_matrix.npz
# Experiment:  3
# MMR Score for query-length/c2 :  0.454208294699
# --- new experiment ---
# data/query-length/c2/tr_c2_suggest_matrix.npz
# data/query-length/c2/val_c2_suggest_matrix.npz
# data/query-length/c2/test_c2_suggest_matrix.npz
# Experiment:  4
# MMR Score for query-length/c2 :  0.445907012581
# --- new experiment ---
# data/query-length/c2/tr_c2_suggest_matrix.npz
# data/query-length/c2/val_c2_suggest_matrix.npz
# data/query-length/c2/test_c2_suggest_matrix.npz
# Experiment:  5
# MMR Score for query-length/c2 :  0.449965262462
# --- new experiment ---
# data/query-length/c2/tr_c2_suggest_matrix.npz
# data/query-length/c2/val_c2_suggest_matrix.npz
# data/query-length/c2/test_c2_suggest_matrix.npz
# Experiment:  6
# MMR Score for query-length/c2 :  0.438829157474
# --- new experiment ---
# data/query-length/c2/tr_c2_suggest_matrix.npz
# data/query-length/c2/val_c2_suggest_matrix.npz
# data/query-length/c2/test_c2_suggest_matrix.npz
# Experiment:  7
# MMR Score for query-length/c2 :  0.4358832144
# --- new experiment ---
# data/query-length/c2/tr_c2_suggest_matrix.npz
# data/query-length/c2/val_c2_suggest_matrix.npz
# data/query-length/c2/test_c2_suggest_matrix.npz
# Experiment:  8
# MMR Score for query-length/c2 :  0.444210883931
# --- new experiment ---
# data/query-length/c2/tr_c2_suggest_matrix.npz
# data/query-length/c2/val_c2_suggest_matrix.npz
# data/query-length/c2/test_c2_suggest_matrix.npz
# Experiment:  9
# MMR Score for query-length/c2 :  0.443028351848
# --- new experiment ---
# data/query-length/c2/tr_c2_suggest_matrix.npz
# data/query-length/c2/val_c2_suggest_matrix.npz
# data/query-length/c2/test_c2_suggest_matrix.npz
# Experiment:  10
# MMR Score for query-length/c2 :  0.452551823516
# --- new experiment ---
# data/query-length/c2/tr_c2_suggest_matrix.npz
# data/query-length/c2/val_c2_suggest_matrix.npz
# data/query-length/c2/test_c2_suggest_matrix.npz
# Experiment:  11
# MMR Score for query-length/c2 :  0.445947478489
# --- new experiment ---
# data/query-length/c2/tr_c2_suggest_matrix.npz
# data/query-length/c2/val_c2_suggest_matrix.npz
# data/query-length/c2/test_c2_suggest_matrix.npz
# Experiment:  12
# MMR Score for query-length/c2 :  0.450536712475
# --- new experiment ---
# data/query-length/c2/tr_c2_suggest_matrix.npz
# data/query-length/c2/val_c2_suggest_matrix.npz
# data/query-length/c2/test_c2_suggest_matrix.npz
# Experiment:  13
# MMR Score for query-length/c2 :  0.440829425768
# --- new experiment ---
# data/query-length/c2/tr_c2_suggest_matrix.npz
# data/query-length/c2/val_c2_suggest_matrix.npz
# data/query-length/c2/test_c2_suggest_matrix.npz
# Experiment:  14
# MMR Score for query-length/c2 :  0.44755556654
# --- new experiment ---
# data/query-length/c2/tr_c2_suggest_matrix.npz
# data/query-length/c2/val_c2_suggest_matrix.npz
# data/query-length/c2/test_c2_suggest_matrix.npz
# Experiment:  15
# MMR Score for query-length/c2 :  0.446220191122
# --- new experiment ---
# data/query-length/c2/tr_c2_suggest_matrix.npz
# data/query-length/c2/val_c2_suggest_matrix.npz
# data/query-length/c2/test_c2_suggest_matrix.npz
# Experiment:  16
# MMR Score for query-length/c2 :  0.455658131798
# --- new experiment ---
# data/query-length/c2/tr_c2_suggest_matrix.npz
# data/query-length/c2/val_c2_suggest_matrix.npz
# data/query-length/c2/test_c2_suggest_matrix.npz
# Experiment:  17
# MMR Score for query-length/c2 :  0.437201523096
# --- new experiment ---
# data/query-length/c2/tr_c2_suggest_matrix.npz
# data/query-length/c2/val_c2_suggest_matrix.npz
# data/query-length/c2/test_c2_suggest_matrix.npz
# Experiment:  18
# MMR Score for query-length/c2 :  0.44056120884
# --- new experiment ---
# data/query-length/c2/tr_c2_suggest_matrix.npz
# data/query-length/c2/val_c2_suggest_matrix.npz
# data/query-length/c2/test_c2_suggest_matrix.npz
# Experiment:  19
# MMR Score for query-length/c2 :  0.44708706197
# --- new experiment ---
# data/query-length/c2/tr_c2_suggest_matrix.npz
# data/query-length/c2/val_c2_suggest_matrix.npz
# data/query-length/c2/test_c2_suggest_matrix.npz
# Experiment:  20
# MMR Score for query-length/c2 :  0.450276923973
# --- new experiment ---
# data/query-length/c3/tr_c3_suggest_matrix.npz
# data/query-length/c3/val_c3_suggest_matrix.npz
# data/query-length/c3/test_c3_suggest_matrix.npz
# Experiment:  1
# MMR Score for query-length/c3 :  0.446366899658
# --- new experiment ---
# data/query-length/c3/tr_c3_suggest_matrix.npz
# data/query-length/c3/val_c3_suggest_matrix.npz
# data/query-length/c3/test_c3_suggest_matrix.npz
# Experiment:  2
# MMR Score for query-length/c3 :  0.445871211264
# --- new experiment ---
# data/query-length/c3/tr_c3_suggest_matrix.npz
# data/query-length/c3/val_c3_suggest_matrix.npz
# data/query-length/c3/test_c3_suggest_matrix.npz
# Experiment:  3
# MMR Score for query-length/c3 :  0.439760830363
# --- new experiment ---
# data/query-length/c3/tr_c3_suggest_matrix.npz
# data/query-length/c3/val_c3_suggest_matrix.npz
# data/query-length/c3/test_c3_suggest_matrix.npz
# Experiment:  4
# MMR Score for query-length/c3 :  0.444654290186
# --- new experiment ---
# data/query-length/c3/tr_c3_suggest_matrix.npz
# data/query-length/c3/val_c3_suggest_matrix.npz
# data/query-length/c3/test_c3_suggest_matrix.npz
# Experiment:  5
# MMR Score for query-length/c3 :  0.446512140022
# --- new experiment ---
# data/query-length/c3/tr_c3_suggest_matrix.npz
# data/query-length/c3/val_c3_suggest_matrix.npz
# data/query-length/c3/test_c3_suggest_matrix.npz
# Experiment:  6
# MMR Score for query-length/c3 :  0.456599426418
# --- new experiment ---
# data/query-length/c3/tr_c3_suggest_matrix.npz
# data/query-length/c3/val_c3_suggest_matrix.npz
# data/query-length/c3/test_c3_suggest_matrix.npz
# Experiment:  7
# MMR Score for query-length/c3 :  0.442325853543
# --- new experiment ---
# data/query-length/c3/tr_c3_suggest_matrix.npz
# data/query-length/c3/val_c3_suggest_matrix.npz
# data/query-length/c3/test_c3_suggest_matrix.npz
# Experiment:  8
# MMR Score for query-length/c3 :  0.437781881336
# --- new experiment ---
# data/query-length/c3/tr_c3_suggest_matrix.npz
# data/query-length/c3/val_c3_suggest_matrix.npz
# data/query-length/c3/test_c3_suggest_matrix.npz
# Experiment:  9
# MMR Score for query-length/c3 :  0.444559468731
# --- new experiment ---
# data/query-length/c3/tr_c3_suggest_matrix.npz
# data/query-length/c3/val_c3_suggest_matrix.npz
# data/query-length/c3/test_c3_suggest_matrix.npz
# Experiment:  10
# MMR Score for query-length/c3 :  0.437829807033
# --- new experiment ---
# data/query-length/c3/tr_c3_suggest_matrix.npz
# data/query-length/c3/val_c3_suggest_matrix.npz
# data/query-length/c3/test_c3_suggest_matrix.npz
# Experiment:  11
# MMR Score for query-length/c3 :  0.442965486509
# --- new experiment ---
# data/query-length/c3/tr_c3_suggest_matrix.npz
# data/query-length/c3/val_c3_suggest_matrix.npz
# data/query-length/c3/test_c3_suggest_matrix.npz
# Experiment:  12
# MMR Score for query-length/c3 :  0.443441645292
# --- new experiment ---
# data/query-length/c3/tr_c3_suggest_matrix.npz
# data/query-length/c3/val_c3_suggest_matrix.npz
# data/query-length/c3/test_c3_suggest_matrix.npz
# Experiment:  13
# MMR Score for query-length/c3 :  0.436153812507
# --- new experiment ---
# data/query-length/c3/tr_c3_suggest_matrix.npz
# data/query-length/c3/val_c3_suggest_matrix.npz
# data/query-length/c3/test_c3_suggest_matrix.npz
# Experiment:  14
# MMR Score for query-length/c3 :  0.444171508276
# --- new experiment ---
# data/query-length/c3/tr_c3_suggest_matrix.npz
# data/query-length/c3/val_c3_suggest_matrix.npz
# data/query-length/c3/test_c3_suggest_matrix.npz
# Experiment:  15
# MMR Score for query-length/c3 :  0.442946121765
# --- new experiment ---
# data/query-length/c3/tr_c3_suggest_matrix.npz
# data/query-length/c3/val_c3_suggest_matrix.npz
# data/query-length/c3/test_c3_suggest_matrix.npz
# Experiment:  16
# MMR Score for query-length/c3 :  0.428978404629
# --- new experiment ---
# data/query-length/c3/tr_c3_suggest_matrix.npz
# data/query-length/c3/val_c3_suggest_matrix.npz
# data/query-length/c3/test_c3_suggest_matrix.npz
# Experiment:  17
# MMR Score for query-length/c3 :  0.446959901959
# --- new experiment ---
# data/query-length/c3/tr_c3_suggest_matrix.npz
# data/query-length/c3/val_c3_suggest_matrix.npz
# data/query-length/c3/test_c3_suggest_matrix.npz
# Experiment:  18
# MMR Score for query-length/c3 :  0.44095548415
# --- new experiment ---
# data/query-length/c3/tr_c3_suggest_matrix.npz
# data/query-length/c3/val_c3_suggest_matrix.npz
# data/query-length/c3/test_c3_suggest_matrix.npz
# Experiment:  19
# MMR Score for query-length/c3 :  0.44129647877
# --- new experiment ---
# data/query-length/c3/tr_c3_suggest_matrix.npz
# data/query-length/c3/val_c3_suggest_matrix.npz
# data/query-length/c3/test_c3_suggest_matrix.npz
# Experiment:  20
# MMR Score for query-length/c3 :  0.446468678644
# --- new experiment ---
# data/train_suggest_matrix.npz
# data/val_suggest_matrix.npz
# data/test_suggest_matrix.npz
# Experiment:  1
# MMR Score for  :  0.466923936961
# --- new experiment ---
# data/train_suggest_matrix.npz
# data/val_suggest_matrix.npz
# data/test_suggest_matrix.npz
# Experiment:  2
# MMR Score for  :  0.460889189792
# --- new experiment ---
# data/train_suggest_matrix.npz
# data/val_suggest_matrix.npz
# data/test_suggest_matrix.npz
# Experiment:  3
# MMR Score for  :  0.472343957849
# --- new experiment ---
# data/train_suggest_matrix.npz
# data/val_suggest_matrix.npz
# data/test_suggest_matrix.npz
# Experiment:  4
# MMR Score for  :  0.467059100545
# --- new experiment ---
# data/train_suggest_matrix.npz
# data/val_suggest_matrix.npz
# data/test_suggest_matrix.npz
# Experiment:  5
# MMR Score for  :  0.460562363134
# --- new experiment ---
# data/train_suggest_matrix.npz
# data/val_suggest_matrix.npz
# data/test_suggest_matrix.npz
# Experiment:  6
# MMR Score for  :  0.458796485132
# --- new experiment ---
# data/train_suggest_matrix.npz
# data/val_suggest_matrix.npz
# data/test_suggest_matrix.npz
# Experiment:  7
# MMR Score for  :  0.462169986336
# --- new experiment ---
# data/train_suggest_matrix.npz
# data/val_suggest_matrix.npz
# data/test_suggest_matrix.npz
# Experiment:  8
# MMR Score for  :  0.457292763141
# --- new experiment ---
# data/train_suggest_matrix.npz
# data/val_suggest_matrix.npz
# data/test_suggest_matrix.npz
# Experiment:  9
# MMR Score for  :  0.455372009056
# --- new experiment ---
# data/train_suggest_matrix.npz
# data/val_suggest_matrix.npz
# data/test_suggest_matrix.npz
# Experiment:  10
# MMR Score for  :  0.458738975735
# --- new experiment ---
# data/train_suggest_matrix.npz
# data/val_suggest_matrix.npz
# data/test_suggest_matrix.npz
# Experiment:  11
# MMR Score for  :  0.456681124591
# --- new experiment ---
# data/train_suggest_matrix.npz
# data/val_suggest_matrix.npz
# data/test_suggest_matrix.npz
# Experiment:  12
# MMR Score for  :  0.462077909381
# --- new experiment ---
# data/train_suggest_matrix.npz
# data/val_suggest_matrix.npz
# data/test_suggest_matrix.npz
# Experiment:  13
# MMR Score for  :  0.460567992681
# --- new experiment ---
# data/train_suggest_matrix.npz
# data/val_suggest_matrix.npz
# data/test_suggest_matrix.npz
# Experiment:  14
# MMR Score for  :  0.461129303477
# --- new experiment ---
# data/train_suggest_matrix.npz
# data/val_suggest_matrix.npz
# data/test_suggest_matrix.npz
# Experiment:  15
# MMR Score for  :  0.467320040794
# --- new experiment ---
# data/train_suggest_matrix.npz
# data/val_suggest_matrix.npz
# data/test_suggest_matrix.npz
# Experiment:  16
# MMR Score for  :  0.451929825929
# --- new experiment ---
# data/train_suggest_matrix.npz
# data/val_suggest_matrix.npz
# data/test_suggest_matrix.npz
# Experiment:  17
# MMR Score for  :  0.468893215615
# --- new experiment ---
# data/train_suggest_matrix.npz
# data/val_suggest_matrix.npz
# data/test_suggest_matrix.npz
# Experiment:  18
# MMR Score for  :  0.464684187159
# --- new experiment ---
# data/train_suggest_matrix.npz
# data/val_suggest_matrix.npz
# data/test_suggest_matrix.npz
# Experiment:  19
# MMR Score for  :  0.464675433105
# --- new experiment ---
# data/train_suggest_matrix.npz
# data/val_suggest_matrix.npz
# data/test_suggest_matrix.npz
# Experiment:  20
# MMR Score for  :  0.461078592195
# __________________________________________________
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  1
# MMR Score for long-tail :  0.387093644681
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  2
# MMR Score for long-tail :  0.364124361555
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  3
# MMR Score for long-tail :  0.320739140259
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  4
# MMR Score for long-tail :  0.385433749932
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  5
# MMR Score for long-tail :  0.38175144238
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  6
# MMR Score for long-tail :  0.370655580892
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  7
# MMR Score for long-tail :  0.355856432718
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  8
# MMR Score for long-tail :  0.384138180191
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  9
# MMR Score for long-tail :  0.390291604448
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  10
# MMR Score for long-tail :  0.432227978204
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  11
# MMR Score for long-tail :  0.395308011482
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  12
# MMR Score for long-tail :  0.408544551871
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  13
# MMR Score for long-tail :  0.393247664191
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  14
# MMR Score for long-tail :  0.422040128397
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  15
# MMR Score for long-tail :  0.379367806447
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  16
# MMR Score for long-tail :  0.37433422396
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  17
# MMR Score for long-tail :  0.368435246748
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  18
# MMR Score for long-tail :  0.409709650721
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  19
# MMR Score for long-tail :  0.423442764992
# --- new experiment ---
# data/long-tail/train_longtail_suggest_matrix.npz
# data/long-tail/val_longtail_suggest_matrix.npz
# data/long-tail/test_longtail_suggest_matrix.npz
# Experiment:  20
# MMR Score for long-tail :  0.371474788137
# --- new experiment ---
# data/noisy/tr_noisy_suggest_matrix.npz
# data/noisy/val_noisy_suggest_matrix.npz
# data/noisy/test_noisy_suggest_matrix.npz
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-36747abb5293> in <module>()
#      30             )
#      31
# ---> 32             model.fit(train_data_features, train_data_label_scores, train_data_session_ids)
#      33
#      34             Epred = model.predict(test_data_features)
#
# /Users/Maurits/anaconda/lib/python2.7/site-packages/pyltr-0.1.0-py2.7.egg/pyltr/models/lambdamart.pyc in fit(self, X, y, qids, monitor)
#     199
#     200         n_stages = self._fit_stages(X, y, qids, y_pred,
# --> 201                                     random_state, begin_at_stage, monitor)
#     202
#     203         if n_stages < self.estimators_.shape[0]:
#
# /Users/Maurits/anaconda/lib/python2.7/site-packages/pyltr-0.1.0-py2.7.egg/pyltr/models/lambdamart.pyc in _fit_stages(self, X, y, qids, y_pred, random_state, begin_at_stage, monitor)
#     409             y_pred = self._fit_stage(i, X, y, qids, y_pred, sample_weight,
#     410                                      sample_mask, query_groups_to_use,
# --> 411                                      random_state)
#     412
#     413             train_total_score, oob_total_score = 0.0, 0.0
#
# /Users/Maurits/anaconda/lib/python2.7/site-packages/pyltr-0.1.0-py2.7.egg/pyltr/models/lambdamart.pyc in _fit_stage(self, i, X, y, qids, y_pred, sample_weight, sample_mask, query_groups, random_state)
#     355
#     356         tree.fit(X, all_lambdas, sample_weight=sample_weight,
# --> 357                  check_input=False)
#     358
#     359         self._update_terminal_regions(tree.tree_, X, y, all_lambdas,
#
# /Users/Maurits/anaconda/lib/python2.7/site-packages/sklearn/tree/tree.pyc in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1027             sample_weight=sample_weight,
#    1028             check_input=check_input,
# -> 1029             X_idx_sorted=X_idx_sorted)
#    1030         return self
#    1031
#
# /Users/Maurits/anaconda/lib/python2.7/site-packages/sklearn/tree/tree.pyc in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     302         # matrix into each tree.
#     303         if X_idx_sorted is None and presort:
# --> 304             X_idx_sorted = np.asfortranarray(np.argsort(X, axis=0),
#     305                                              dtype=np.int32)
#     306
#
# /Users/Maurits/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in argsort(a, axis, kind, order)
#     912     except AttributeError:
#     913         return _wrapit(a, 'argsort', axis, kind, order)
# --> 914     return argsort(axis, kind, order)
#     915
#     916
#
# KeyboardInterrupt:

# %%
"""
ADJ model implementation
"""





val_data_anchor_ids, val_data_suggestion_ids, val_data_features, \
val_data_label_scores, val_data_session_ids =  make_data(DATA_FOLDER, '', file_dict,'train' ,feature_idx=4) 

test_data_anchor_ids, test_data_suggestion_ids, test_data_features, \
test_data_label_scores, test_data_session_ids =  make_data(DATA_FOLDER, 'query-length/c3', file_dict,'test' ,feature_idx=4)

print val_data_label_scores.shape
print test_data_label_scores.shape
# Out:
# data/train_suggest_matrix.npz
# data/query-length/c3/test_c3_suggest_matrix.npz
# (359200,)
# (146260,)

# %%
"""
def MMR_Score(Epred, test_data_session_ids, test_data_label_scores, session_length=20):
    sessions = len(test_data_session_ids)/session_length
    idx_array = []

    for session_idx in range(0, sessions):
        predicted_scores = Epred[session_idx*session_length:(session_idx +1)*session_length]
        labels = test_data_label_scores[session_idx*session_length:(session_idx +1)*session_length]
        merged = np.array([predicted_scores, labels]).T
        
        merged = merged[merged[:, 0].argsort()]

        pred_idx = np.argmax(merged[:,1][::-1]) 
        idx_array.append(pred_idx)
 
    idx_array = np.histogram(idx_array)[0]

    sum_score = 0
    for i,val in enumerate(idx_array):
        print (1./(i+1)) * val
        sum_score += (1./(i+1)) * val
    return sum_score / sessions

"""

print MRR_Score(val_data_features[:,0], val_data_session_ids,  val_data_label_scores)
print MRR_Score(test_data_features[:,0], test_data_session_ids,  test_data_label_scores)
# Out:
# 0.30775179996
# 0.310757548371

# %%
labels  = [1,0,0,0,1,0,0,0,1]
test_data_session_ids = [1,1,1,2,2,2,3,3,3]
features = [9,1,1,9,3,1,3,2,1]

# %%
MMR_Score(features, test_data_session_ids,  labels, session_length=3)

# %%
result_dict
# Out:
# {'': [0.5405383144324033,
#   0.5399769710790338,
#   0.550276722372385,
#   0.5442619284362216,
#   0.5488963220814814,
#   0.537359104769452,
#   0.5498841321213621,
#   0.5457360616759168,
#   0.5485279752534448,
#   0.5489958412994321],
#  'long-tail': [0.5086193641149739,
#   0.5192673730153502,
#   0.5087087792420795,
#   0.5139729755973782,
#   0.5209165904552708,
#   0.5303805969797115,
#   0.49766256200264025,
#   0.48548909549391805,
#   0.4870286420621442,
#   0.4917389813151992],
#  'noisy': [0.5443452907631605,
#   0.5486075093736763,
#   0.5445594912715378,
#   0.5435193089131723,
#   0.5391056944870003,
#   0.5459361305351251,
#   0.5372110274901023,
#   0.5420938292981136,
#   0.534830523908856,
#   0.542607522451403],
#  'query-length/c1': [0.541545965265918,
#   0.5392176245051008,
#   0.5392592597939515,
#   0.5323738830713733,
#   0.5337458503060749,
#   0.5422357685473888,
#   0.5459774901251432,
#   0.5375598411738897,
#   0.5352421772328387,
#   0.5410496106741213],
#  'query-length/c2': [0.5469503800815595,
#   0.5400502085841963,
#   0.5401652220368754,
#   0.5300648798441066,
#   0.545295372611902,
#   0.5395878934418971,
#   0.5425272983730365,
#   0.5451490936334444,
#   0.5386530089767069,
#   0.5466080294678509],
#  'query-length/c3': [0.5436402150986621,
#   0.5447444181045317,
#   0.5468529011781859,
#   0.5453625050543345,
#   0.5439121663615588,
#   0.5494512037451645,
#   0.5383394732857377,
#   0.5421739675153591,
#   0.5390275045349306,
#   0.5380369832635578]}
